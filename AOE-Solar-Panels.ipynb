# %%
1+2
# Out:
# 3

# %%
120*20*2
# Out:
# 4800

# %%
120*20*2
# Out:
# 4800

# %%
import numpy as np
import math

# %%
a = [1-0.01672*math.cos(0.9856*(i-4)*math.pi/180) for i in range (5,370)]

# %%
days = np.array(a)

# %%
days
# Out:
# array([0.98328247, 0.98328989, 0.98330226, 0.98331956, 0.98334181,
#        0.98336898, 0.98340107, 0.98343807, 0.98347998, 0.98352677,
#        0.98357844, 0.98363496, 0.98369633, 0.98376252, 0.98383352,
#        0.9839093 , 0.98398984, 0.98407512, 0.98416512, 0.98425979,
#        0.98435913, 0.98446309, 0.98457165, 0.98468478, 0.98480244,
#        0.98492459, 0.9850512 , 0.98518224, 0.98531767, 0.98545743,
#        0.98560151, 0.98574984, 0.98590238, 0.9860591 , 0.98621995,
#        0.98638487, 0.98655382, 0.98672675, 0.98690361, 0.98708434,
#        0.9872689 , 0.98745722, 0.98764925, 0.98784494, 0.98804422,
#        0.98824704, 0.98845334, 0.98866306, 0.98887613, 0.98909249,
#        0.98931208, 0.98953483, 0.98976068, 0.98998956, 0.9902214 ,
#        0.99045614, 0.99069369, 0.99093401, 0.991177  , 0.99142261,
#        0.99167075, 0.99192136, 0.99217436, 0.99242967, 0.99268723,
#        0.99294694, 0.99320875, 0.99347256, 0.99373831, 0.99400591,
# ...

# %%
durationList = """ h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m
 01     09:19    10:08    11:17    12:41    13:58    14:54    15:02    14:19    13:05    11:46    10:26    09:29
 02     09:20    10:10    11:20    12:44    14:00    14:55    15:02    14:17    13:03    11:43    10:24    09:27
 03     09:21    10:12    11:23    12:47    14:02    14:56    15:01    14:15    13:00    11:40    10:21    09:26
 04     09:22    10:14    11:25    12:49    14:04    14:57    15:00    14:12    12:57    11:38    10:19    09:25
 05     09:23    10:17    11:28    12:52    14:07    14:58    15:00    14:10    12:55    11:35    10:17    09:24
 06     09:24    10:19    11:31    12:55    14:09    14:59    14:59    14:08    12:52    11:32    10:14    09:23
 07     09:25    10:21    11:33    12:57    14:11    15:00    14:58    14:06    12:49    11:30    10:12    09:22
 08     09:26    10:24    11:36    13:00    14:13    15:01    14:57    14:04    12:47    11:27    10:10    09:21
 09     09:27    10:26    11:39    13:03    14:15    15:02    14:56    14:01    12:44    11:24    10:08    09:20
 10     09:28    10:29    11:42    13:05    14:17    15:02    14:55    13:59    12:42    11:22    10:05    09:19
 11     09:30    10:31    11:44    13:08    14:19    15:03    14:53    13:57    12:39    11:19    10:03    09:19
 12     09:31    10:33    11:47    13:10    14:21    15:03    14:52    13:55    12:36    11:16    10:01    09:18
 13     09:32    10:36    11:50    13:13    14:23    15:04    14:51    13:52    12:34    11:14    09:59    09:17
 14     09:34    10:38    11:52    13:16    14:25    15:04    14:50    13:50    12:31    11:11    09:57    09:17
 15     09:35    10:41    11:55    13:18    14:27    15:05    14:48    13:48    12:28    11:08    09:55    09:17
 16     09:37    10:43    11:58    13:21    14:29    15:05    14:47    13:45    12:26    11:06    09:53    09:16
 17     09:39    10:46    12:01    13:23    14:31    15:05    14:45    13:43    12:23    11:03    09:51    09:16
 18     09:40    10:49    12:03    13:26    14:33    15:06    14:44    13:40    12:20    11:01    09:49    09:16
 19     09:42    10:51    12:06    13:28    14:35    15:06    14:42    13:38    12:18    10:58    09:47    09:15
 20     09:44    10:54    12:09    13:31    14:37    15:06    14:41    13:36    12:15    10:56    09:46    09:15
 21     09:45    10:56    12:11    13:33    14:38    15:06    14:39    13:33    12:12    10:53    09:44    09:15
 22     09:47    10:59    12:14    13:36    14:40    15:06    14:37    13:31    12:10    10:51    09:42    09:15
 23     09:49    11:01    12:17    13:38    14:41    15:06    14:36    13:28    12:07    10:48    09:40    09:15
 24     09:51    11:04    12:20    13:41    14:43    15:05    14:34    13:26    12:04    10:45    09:39    09:15
 25     09:53    11:07    12:22    13:43    14:45    15:05    14:32    13:23    12:02    10:43    09:37    09:16
 26     09:55    11:09    12:25    13:46    14:46    15:05    14:30    13:21    11:59    10:40    09:36    09:16
 27     09:57    11:12    12:28    13:48    14:48    15:05    14:28    13:18    11:56    10:38    09:34    09:16
 28     09:59    11:15    12:30    13:51    14:49    15:04    14:27    13:15    11:54    10:36    09:33    09:17
 29     10:01             12:33    13:53    14:50    15:04    14:25    13:13    11:51    10:33    09:31    09:17
 30     10:03             12:36    13:55    14:52    15:03    14:23    13:10    11:48    10:31    09:30    09:18
 31     10:06             12:38             14:53             14:21    13:08             10:28             09:18"""

# %%
durationList
# Out:
# ' h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m     h  m\n 01     09:19    10:08    11:17    12:41    13:58    14:54    15:02    14:19    13:05    11:46    10:26    09:29\n 02     09:20    10:10    11:20    12:44    14:00    14:55    15:02    14:17    13:03    11:43    10:24    09:27\n 03     09:21    10:12    11:23    12:47    14:02    14:56    15:01    14:15    13:00    11:40    10:21    09:26\n 04     09:22    10:14    11:25    12:49    14:04    14:57    15:00    14:12    12:57    11:38    10:19    09:25\n 05     09:23    10:17    11:28    12:52    14:07    14:58    15:00    14:10    12:55    11:35    10:17    09:24\n 06     09:24    10:19    11:31    12:55    14:09    14:59    14:59    14:08    12:52    11:32    10:14    09:23\n 07     09:25    10:21    11:33    12:57    14:11    15:00    14:58    14:06    12:49    11:30    10:12    09:22\n 08     09:26    10:24    11:36    13:00    14:13    15:01    14:57    14:04    12:47    11:2
# ...

# %%
len(durationList)
# Out:
# 3607

# %%
timeList = []
for i in range (0,12):
    timeList.append([])
for i in range (2, len(durationList)-3):
    if (durationList[i] == ':'):
        time = int(durationList[i-2:i]) + int(durationList[i+1:i+3])/60
        timeList.append(time)

# %%
timeList
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  9.316666666666666,
#  10.133333333333333,
#  11.283333333333333,
#  12.683333333333334,
#  13.966666666666667,
#  14.9,
#  15.033333333333333,
#  14.316666666666666,
#  13.083333333333334,
#  11.766666666666667,
#  10.433333333333334,
#  9.483333333333333,
#  9.333333333333334,
#  10.166666666666666,
#  11.333333333333334,
#  12.733333333333333,
#  14.0,
#  14.916666666666666,
#  15.033333333333333,
#  14.283333333333333,
#  13.05,
#  11.716666666666667,
#  10.4,
#  9.45,
#  9.35,
#  10.2,
#  11.383333333333333,
#  12.783333333333333,
#  14.033333333333333,
#  14.933333333333334,
#  15.016666666666667,
#  14.25,
#  13.0,
#  11.666666666666666,
#  10.35,
#  9.433333333333334,
#  9.366666666666667,
#  10.233333333333333,
#  11.416666666666666,
#  12.816666666666666,
#  14.066666666666666,
#  14.95,
#  15.0,
#  14.2,
#  12.95,
#  11.633333333333333,
#  10.316666666666666,
#  9.416666666666666,
# ...

# %%
l = []

# %%
import csv

# %%
from numpy import genfromtxt
my_data = genfromtxt('sunlightdata.csv', delimiter=',')
import pandas as pd

# %%
my_data = pd.read_csv('sunlightdata.csv')

# %%
my_data
# Out:
#     Day   Jan.   Feb.   Mar.   Apr.    May   June   July   Aug.   Sep.   Oct.  \
# 0     1   9:19  10:08  11:17  12:41  13:58  14:54  15:02  14:19  13:05  11:46
# 1     2   9:20  10:10  11:20  12:44  14:00  14:55  15:02  14:17  13:03  11:43
# 2     3   9:21  10:12  11:23  12:47  14:02  14:56  15:01  14:15  13:00  11:40
# 3     4   9:22  10:14  11:25  12:49  14:04  14:57  15:00  14:12  12:57  11:38
# 4     5   9:23  10:17  11:28  12:52  14:07  14:58  15:00  14:10  12:55  11:35
# 5     6   9:24  10:19  11:31  12:55  14:09  14:59  14:59  14:08  12:52  11:32
# 6     7   9:25  10:21  11:33  12:57  14:11  15:00  14:58  14:06  12:49  11:30
# 7     8   9:26  10:24  11:36  13:00  14:13  15:01  14:57  14:04  12:47  11:27
# 8     9   9:27  10:26  11:39  13:03  14:15  15:02  14:56  14:01  12:44  11:24
# 9    10   9:28  10:29  11:42  13:05  14:17  15:02  14:55  13:59  12:42  11:22
# 10   11   9:30  10:31  11:44  13:08  14:19  15:03  14:53  13:57  12:39  11:19
# ...

# %%
my_data["Jan."][0] = "9:19"
# Out:
# /Users/bill/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for month in my_data.columns:
    i=0;
    if(month == "Day"):
        continue
    for time in my_data[month]:
        if(str(time).find(":")!=-1):
            print(time)
            my_data[month][i]=int(time[time.find(":")+1:time.find(":")+3])/60 + int(time[:time.find(":")])
        i+=1
# Out:
# /Users/bill/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 9:19
# 9:20
# 9:21
# 9:22
# 9:23
# 9:24
# 9:25
# 9:26
# 9:27
# 9:28
# 9:30
# 9:31
# 9:32
# 9:34
# 9:35
# 9:37
# 9:39
# 9:40
# 9:42
# 9:44
# 9:45
# 9:47
# 9:49
# 9:51
# 9:53
# 9:55
# 9:57
# 9:59
# 10:01
# 10:03
# 10:06
# 10:08
# 10:10
# 10:12
# 10:14
# 10:17
# 10:19
# 10:21
# 10:24
# 10:26
# 10:29
# 10:31
# 10:33
# 10:36
# 10:38
# 10:41
# 10:43
# 10:46
# 10:49
# 10:51
# 10:54
# 10:56
# 10:59
# 11:01
# 11:04
# 11:07
# 11:09
# 11:12
# 11:15
# 11:17
# 11:20
# 11:23
# 11:25
# 11:28
# 11:31
# 11:33
# 11:36
# 11:39
# 11:42
# 11:44
# 11:47
# 11:50
# 11:52
# 11:55
# 11:58
# 12:01
# 12:03
# 12:06
# 12:09
# 12:11
# 12:14
# 12:17
# 12:20
# 12:22
# 12:25
# 12:28
# 12:30
# 12:33
# 12:36
# 12:38
# 12:41
# ...

# %%
type(my_data["Jan."][0])
# Out:
# float

# %%
my_data
# Out:
#     Day     Jan.     Feb.     Mar.     Apr.      May     June     July  \
# 0     1  9.31667  10.1333  11.2833  12.6833  13.9667     14.9  15.0333
# 1     2  9.33333  10.1667  11.3333  12.7333       14  14.9167  15.0333
# 2     3     9.35     10.2  11.3833  12.7833  14.0333  14.9333  15.0167
# 3     4  9.36667  10.2333  11.4167  12.8167  14.0667    14.95       15
# 4     5  9.38333  10.2833  11.4667  12.8667  14.1167  14.9667       15
# 5     6      9.4  10.3167  11.5167  12.9167    14.15  14.9833  14.9833
# 6     7  9.41667    10.35    11.55    12.95  14.1833       15  14.9667
# 7     8  9.43333     10.4     11.6       13  14.2167  15.0167    14.95
# 8     9     9.45  10.4333    11.65    13.05    14.25  15.0333  14.9333
# 9    10  9.46667  10.4833     11.7  13.0833  14.2833  15.0333  14.9167
# 10   11      9.5  10.5167  11.7333  13.1333  14.3167    15.05  14.8833
# 11   12  9.51667    10.55  11.7833  13.1667    14.35    15.05  14.8667
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure; my_data.plot;

# %%
df = my_data.cumsum()

# %%
plt.figure(); my_data.plot();

# %%
sum(list(my_data.count())[1:])
# Out:
# 365

# %%
len(timeList)
# Out:
# 376

# %%
len(days)
# Out:
# 365

# %%
my_data
# Out:
#     Day     Jan.     Feb.     Mar.     Apr.      May     June     July  \
# 0     1  9.31667  10.1333  11.2833  12.6833  13.9667     14.9  15.0333
# 1     2  9.33333  10.1667  11.3333  12.7333       14  14.9167  15.0333
# 2     3     9.35     10.2  11.3833  12.7833  14.0333  14.9333  15.0167
# 3     4  9.36667  10.2333  11.4167  12.8167  14.0667    14.95       15
# 4     5  9.38333  10.2833  11.4667  12.8667  14.1167  14.9667       15
# 5     6      9.4  10.3167  11.5167  12.9167    14.15  14.9833  14.9833
# 6     7  9.41667    10.35    11.55    12.95  14.1833       15  14.9667
# 7     8  9.43333     10.4     11.6       13  14.2167  15.0167    14.95
# 8     9     9.45  10.4333    11.65    13.05    14.25  15.0333  14.9333
# 9    10  9.46667  10.4833     11.7  13.0833  14.2833  15.0333  14.9167
# 10   11      9.5  10.5167  11.7333  13.1333  14.3167    15.05  14.8833
# 11   12  9.51667    10.55  11.7833  13.1667    14.35    15.05  14.8667
# ...

# %%
days
# Out:
# array([0.98328247, 0.98328989, 0.98330226, 0.98331956, 0.98334181,
#        0.98336898, 0.98340107, 0.98343807, 0.98347998, 0.98352677,
#        0.98357844, 0.98363496, 0.98369633, 0.98376252, 0.98383352,
#        0.9839093 , 0.98398984, 0.98407512, 0.98416512, 0.98425979,
#        0.98435913, 0.98446309, 0.98457165, 0.98468478, 0.98480244,
#        0.98492459, 0.9850512 , 0.98518224, 0.98531767, 0.98545743,
#        0.98560151, 0.98574984, 0.98590238, 0.9860591 , 0.98621995,
#        0.98638487, 0.98655382, 0.98672675, 0.98690361, 0.98708434,
#        0.9872689 , 0.98745722, 0.98764925, 0.98784494, 0.98804422,
#        0.98824704, 0.98845334, 0.98866306, 0.98887613, 0.98909249,
#        0.98931208, 0.98953483, 0.98976068, 0.98998956, 0.9902214 ,
#        0.99045614, 0.99069369, 0.99093401, 0.991177  , 0.99142261,
#        0.99167075, 0.99192136, 0.99217436, 0.99242967, 0.99268723,
#        0.99294694, 0.99320875, 0.99347256, 0.99373831, 0.99400591,
# ...

# %%
distance = days * 1.496e+11

# %%
distance
# Out:
# array([1.47099058e+11, 1.47100168e+11, 1.47102018e+11, 1.47104607e+11,
#        1.47107934e+11, 1.47111999e+11, 1.47116800e+11, 1.47122336e+11,
#        1.47128605e+11, 1.47135605e+11, 1.47143334e+11, 1.47151790e+11,
#        1.47160971e+11, 1.47170874e+11, 1.47181495e+11, 1.47192832e+11,
#        1.47204881e+11, 1.47217639e+11, 1.47231101e+11, 1.47245265e+11,
#        1.47260126e+11, 1.47275678e+11, 1.47291919e+11, 1.47308843e+11,
#        1.47326444e+11, 1.47344719e+11, 1.47363660e+11, 1.47383264e+11,
#        1.47403523e+11, 1.47424432e+11, 1.47445985e+11, 1.47468176e+11,
#        1.47490997e+11, 1.47514442e+11, 1.47538504e+11, 1.47563177e+11,
#        1.47588452e+11, 1.47614322e+11, 1.47640780e+11, 1.47667817e+11,
#        1.47695427e+11, 1.47723600e+11, 1.47752328e+11, 1.47781603e+11,
#        1.47811415e+11, 1.47841758e+11, 1.47872620e+11, 1.47903993e+11,
#        1.47935869e+11, 1.47968237e+11, 1.48001087e+11, 1.48034411e+11,
# ...

# %%
P0 = 3.86e26

# %%
intensities = P0/(math.pi*4*distance**2)

# %%
intensities
# Out:
# array([1419.57275982, 1419.55133414, 1419.5156328 , 1419.46566798,
#        1419.40145671, 1419.32302091, 1419.2303873 , 1419.12358747,
#        1419.00265782, 1418.86763953, 1418.71857859, 1418.55552574,
#        1418.37853645, 1418.18767092, 1417.98299401, 1417.76457526,
#        1417.53248881, 1417.2868134 , 1417.02763232, 1416.75503337,
#        1416.46910882, 1416.16995538, 1415.85767416, 1415.53237057,
#        1415.19415436, 1414.84313949, 1414.47944413, 1414.10319058,
#        1413.71450525, 1413.31351854, 1412.90036484, 1412.47518246,
#        1412.03811354, 1411.58930403, 1411.12890357, 1410.65706549,
#        1410.1739467 , 1409.67970762, 1409.17451214, 1408.65852752,
#        1408.13192435, 1407.59487644, 1407.04756077, 1406.49015741,
#        1405.92284945, 1405.34582291, 1404.75926667, 1404.16337241,
#        1403.55833448, 1402.94434989, 1402.32161817, 1401.69034131,
#        1401.0507237 , 1400.40297202, 1399.74729517, 1399.08390417,
# ...

# %%
min(intensities)*0.50*0.2
# Out:
# 132.7736241319312

# %%
4800/132.77
# Out:
# 36.152745349099945

# %%
def toRadian(x):
    return x*math.pi/180

# %%
delta = [math.asin(math.sin(toRadian(-23.44)) * math.cos(toRadian(360/365.24*(N+10))+360/math.pi*0.0167*math.sin(toRadian(360/365.24*(N-2))))) for N in range (1,365)]

# %%
math.sin(toRadian(-23.44))
# Out:
# -0.39778850739794974

# %%
math.cos(toRadian(360/365.24))
# Out:
# 0.9998520338538996

# %%
delta
# Out:
# [-0.4038251519426844,
#  -0.39991779651279075,
#  -0.39495717269013125,
#  -0.38896338737626096,
#  -0.381960912261393,
#  -0.37397826808712076,
#  -0.3650476721758523,
#  -0.3552046598124061,
#  -0.3444876900003886,
#  -0.33293774558320416,
#  -0.3205979368050353,
#  -0.30751311619400157,
#  -0.29372951128453845,
#  -0.2792943802592056,
#  -0.26425569416867434,
#  -0.24866184805194166,
#  -0.23256140207693968,
#  -0.21600285278595222,
#  -0.1990344336751826,
#  -0.18170394366432716,
#  -0.1640586015106593,
#  -0.146144923876461,
#  -0.12800862454813902,
#  -0.1096945322078837,
#  -0.0912465241523038,
#  -0.07270747341670065,
#  -0.05411920688037393,
#  -0.03552247208222076,
#  -0.01695691065431059,
#  0.001538963525723269,
#  0.019927783162098034,
#  0.038173344844018166,
#  0.05624062611896689,
#  0.0740958034323276,
#  0.09170627183540073,
#  0.10904066717407387,
#  0.12606889128469914,
#  0.14276214054163483,
#  0.15909293792211476,
#  0.17503516857845527,
# ...

# %%
toRadian(180)
# Out:
# 3.141592653589793

# %%
plt.plot(delta)
plt.show()

# %%
phi = []
for value in delta:
    phi.append(math.acos(math.sin(toRadian(40.8107))*math.sin(value)))

# %%
phi
# Out:
# [1.8305161445240734,
#  1.8280851237002285,
#  1.8249952545086794,
#  1.8212566395753087,
#  1.8168817575690475,
#  1.8118853627288503,
#  1.8062843682279968,
#  1.80009771566029,
#  1.793346233078943,
#  1.7860524840830208,
#  1.778240610432297,
#  1.7699361705866843,
#  1.7611659764210632,
#  1.7519579301720873,
#  1.742340863442977,
#  1.7323443798380818,
#  1.7219987025330423,
#  1.711334527819558,
#  1.7003828854053236,
#  1.6891750060071522,
#  1.6777421965544141,
#  1.6661157231246142,
#  1.6543267015656544,
#  1.642405995621007,
#  1.6303841222645148,
#  1.6182911638697455,
#  1.6061566867829533,
#  1.594009665836497,
#  1.5818784143284768,
#  1.5697905190016403,
#  1.5577727795775713,
#  1.545851152438024,
#  1.5340506980914834,
#  1.5223955321170355,
#  1.5109087793371505,
#  1.4996125310337927,
#  1.488527805086324,
#  1.4776745089730938,
#  1.4670714056395842,
#  1.4567360822929445,
#  1.4466849222341536,
#  1.4369330798835835,
#  1.4274944591922314,
# ...

# %%
plt.plot(phi)
plt.show()

# %%
delta = [23.45*math.pi/180*math.sin(toRadian(2*math.pi*(284+n)/36.25)) for n in range (1,366)]

# %%
plt.plot(delta)
plt.show()

# %%
my_data
# Out:
#     Day     Jan.     Feb.     Mar.     Apr.      May     June     July  \
# 0     1  9.31667  10.1333  11.2833  12.6833  13.9667     14.9  15.0333
# 1     2  9.33333  10.1667  11.3333  12.7333       14  14.9167  15.0333
# 2     3     9.35     10.2  11.3833  12.7833  14.0333  14.9333  15.0167
# 3     4  9.36667  10.2333  11.4167  12.8167  14.0667    14.95       15
# 4     5  9.38333  10.2833  11.4667  12.8667  14.1167  14.9667       15
# 5     6      9.4  10.3167  11.5167  12.9167    14.15  14.9833  14.9833
# 6     7  9.41667    10.35    11.55    12.95  14.1833       15  14.9667
# 7     8  9.43333     10.4     11.6       13  14.2167  15.0167    14.95
# 8     9     9.45  10.4333    11.65    13.05    14.25  15.0333  14.9333
# 9    10  9.46667  10.4833     11.7  13.0833  14.2833  15.0333  14.9167
# 10   11      9.5  10.5167  11.7333  13.1333  14.3167    15.05  14.8833
# 11   12  9.51667    10.55  11.7833  13.1667    14.35    15.05  14.8667
# ...

# %%
flattened = my_data.values.flatten()

# %%
len(flattened)
# Out:
# 403

# %%
flattened
# Out:
# array([1, 9.316666666666666, 10.133333333333333, 11.283333333333333,
#        12.683333333333334, 13.966666666666667, 14.9, 15.033333333333333,
#        14.316666666666666, 13.083333333333334, 11.766666666666667,
#        10.433333333333334, 9.483333333333333, 2, 9.333333333333334,
#        10.166666666666666, 11.333333333333334, 12.733333333333333, 14.0,
#        14.916666666666666, 15.033333333333333, 14.283333333333333, 13.05,
#        11.716666666666667, 10.4, 9.45, 3, 9.35, 10.2, 11.383333333333333,
#        12.783333333333333, 14.033333333333333, 14.933333333333334,
#        15.016666666666667, 14.25, 13.0, 11.666666666666666, 10.35,
#        9.433333333333334, 4, 9.366666666666667, 10.233333333333333,
#        11.416666666666666, 12.816666666666666, 14.066666666666666, 14.95,
#        15.0, 14.2, 12.95, 11.633333333333333, 10.316666666666666,
#        9.416666666666666, 5, 9.383333333333333, 10.283333333333333,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-0d6dba166af3> in <module>()
# ----> 1 my_data = my_data[np.logical_not(np.isnan(my_data))]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
my_data.shape
# Out:
# (31, 13)

# %%
for column in my_data:
    print(df[column])
# Out:
# 0       1
# 1       3
# 2       6
# 3      10
# 4      15
# 5      21
# 6      28
# 7      36
# 8      45
# 9      55
# 10     66
# 11     78
# 12     91
# 13    105
# 14    120
# 15    136
# 16    153
# 17    171
# 18    190
# 19    210
# 20    231
# 21    253
# 22    276
# 23    300
# 24    325
# 25    351
# 26    378
# 27    406
# 28    435
# 29    465
# 30    496
# Name: Day, dtype: object
# 0     9.31667
# 1       18.65
# 2          28
# 3     37.3667
# 4       46.75
# 5       56.15
# 6     65.5667
# 7          75
# 8       84.45
# 9     93.9167
# 10    103.417
# 11    112.933
# 12    122.467
# 13    132.033
# 14    141.617
# 15    151.233
# 16    160.883
# 17     170.55
# 18     180.25
# 19    189.983
# 20    199.733
# 21    209.517
# 22    219.333
# 23    229.183
# 24    239.067
# 25    248.983
# 26    258.933
# 27    268.917
# 28    278.933
# 29    288.983
# 30    299.083
# Name: Jan., dtype: object
# 0     10.1333
# 1        20.3
# 2        30.5
# 3     40.7333
# ...

# %%
my_data
# Out:
#     Day     Jan.     Feb.     Mar.     Apr.      May     June     July  \
# 0     1  9.31667  10.1333  11.2833  12.6833  13.9667     14.9  15.0333
# 1     2  9.33333  10.1667  11.3333  12.7333       14  14.9167  15.0333
# 2     3     9.35     10.2  11.3833  12.7833  14.0333  14.9333  15.0167
# 3     4  9.36667  10.2333  11.4167  12.8167  14.0667    14.95       15
# 4     5  9.38333  10.2833  11.4667  12.8667  14.1167  14.9667       15
# 5     6      9.4  10.3167  11.5167  12.9167    14.15  14.9833  14.9833
# 6     7  9.41667    10.35    11.55    12.95  14.1833       15  14.9667
# 7     8  9.43333     10.4     11.6       13  14.2167  15.0167    14.95
# 8     9     9.45  10.4333    11.65    13.05    14.25  15.0333  14.9333
# 9    10  9.46667  10.4833     11.7  13.0833  14.2833  15.0333  14.9167
# 10   11      9.5  10.5167  11.7333  13.1333  14.3167    15.05  14.8833
# 11   12  9.51667    10.55  11.7833  13.1667    14.35    15.05  14.8667
# ...
